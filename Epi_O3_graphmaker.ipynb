# %%
#Essential Constants
from scipy.constants import h, c, hbar, u, k

#Imports from other script/s
from ipynb.fs.full.Conversions_Epimetheus import * #Conversion Doc
from ipynb.fs.full.Atomic_Mass_Key import element #Mass Key File
from ipynb.fs.full.EpiPan_Functions import * #All Functions

#General Imports
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg as la
import itertools
import pandas as pd
# Out:
# /Users/thomascross/opt/anaconda3/lib/python3.8/site-packages/pyscf/dft/libxc.py:771: UserWarning: Since PySCF-2.3, B3LYP (and B3P86) are changed to the VWN-RPA variant, corresponding to the original definition by Stephens et al. (issue 1480) and the same as the B3LYP functional in Gaussian. To restore the VWN5 definition, you can put the setting "B3LYP_WITH_VWN5 = True" in pyscf_conf.py
#   warnings.warn('Since PySCF-2.3, B3LYP (and B3P86) are changed to the VWN-RPA variant, '

# %%
#668 Read In
# %store -r P_nu1_13DaLo_668
# %store -r P_nu1_13DaLo_668_int
# %store -r Q_nu1_13DaLo_668
# %store -r Q_nu1_13DaLo_668_int
# %store -r R_nu1_13DaLo_668
# %store -r R_nu1_13DaLo_668_int
# %store -r P_nu1_13DaLo_668
# %store -r P_nu1_13DaLo_668_int
# %store -r Q_nu1_13DaLo_668
# %store -r Q_nu1_13DaLo_668_int
# %store -r R_nu1_13DaLo_668
# %store -r R_nu1_13DaLo_668_int
# %store -r P_nu2_13DaLo_668
# %store -r P_nu2_13DaLo_668_int
# %store -r Q_nu2_13DaLo_668
# %store -r Q_nu2_13DaLo_668_int
# %store -r R_nu2_13DaLo_668
# %store -r R_nu2_13DaLo_668_int
# %store -r P_nu2_13DaLo_668
# %store -r P_nu2_13DaLo_668_int
# %store -r Q_nu2_13DaLo_668
# %store -r Q_nu2_13DaLo_668_int
# %store -r R_nu2_13DaLo_668
# %store -r R_nu2_13DaLo_668_int
# %store -r P_nu3_13DaLo_668
# %store -r P_nu3_13DaLo_668_int
# %store -r Q_nu3_13DaLo_668
# %store -r Q_nu3_13DaLo_668_int
# %store -r R_nu3_13DaLo_668
# %store -r R_nu3_13DaLo_668_int
# %store -r HITRAN_freq_668_13DaLo
# %store -r HITRAN_int_668_13DaLo

# %%
#686 Read In
# %store -r P_nu1_13DaLo_686
# %store -r P_nu1_13DaLo_686_int
# %store -r Q_nu1_13DaLo_686
# %store -r Q_nu1_13DaLo_686_int
# %store -r R_nu1_13DaLo_686
# %store -r R_nu1_13DaLo_686_int
# %store -r P_nu2_13DaLo_686
# %store -r P_nu2_13DaLo_686_int
# %store -r Q_nu2_13DaLo_686
# %store -r Q_nu2_13DaLo_686_int
# %store -r R_nu2_13DaLo_686
# %store -r R_nu2_13DaLo_686_int
# %store -r P_nu3_13DaLo_686
# %store -r P_nu3_13DaLo_686_int
# %store -r Q_nu3_13DaLo_686
# %store -r Q_nu3_13DaLo_686_int
# %store -r R_nu3_13DaLo_686
# %store -r R_nu3_13DaLo_686_int
# %store -r HITRAN_freq_686_13DaLo
# %store -r HITRAN_int_686_13DaLo

# %%
#667 Read In
# %store -r P_nu1_13DaLo_667
# %store -r P_nu1_13DaLo_667_int
# %store -r Q_nu1_13DaLo_667
# %store -r Q_nu1_13DaLo_667_int
# %store -r R_nu1_13DaLo_667
# %store -r R_nu1_13DaLo_667_int
# %store -r P_nu1_13DaLo_667
# %store -r P_nu1_13DaLo_667_int
# %store -r Q_nu1_13DaLo_667
# %store -r Q_nu1_13DaLo_667_int
# %store -r R_nu1_13DaLo_667
# %store -r R_nu1_13DaLo_667_int
# %store -r P_nu2_13DaLo_667
# %store -r P_nu2_13DaLo_667_int
# %store -r Q_nu2_13DaLo_667
# %store -r Q_nu2_13DaLo_667_int
# %store -r R_nu2_13DaLo_667
# %store -r R_nu2_13DaLo_667_int
# %store -r P_nu2_13DaLo_667
# %store -r P_nu2_13DaLo_667_int
# %store -r Q_nu2_13DaLo_667
# %store -r Q_nu2_13DaLo_667_int
# %store -r R_nu2_13DaLo_667
# %store -r R_nu2_13DaLo_667_int
# %store -r P_nu3_13DaLo_667
# %store -r P_nu3_13DaLo_667_int
# %store -r Q_nu3_13DaLo_667
# %store -r Q_nu3_13DaLo_667_int
# %store -r R_nu3_13DaLo_667
# %store -r R_nu3_13DaLo_667_int
# %store -r HITRAN_freq_667_13DaLo
# %store -r HITRAN_int_667_13DaLo

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex="row", figsize=(16,16))

#ax1

ax1.vlines(P_nu1_13DaLo_668, 0, P_nu1_13DaLo_668_int, "red", label="Ozone 668 - Epimetheus (13DaLo)", linewidth=.5)
ax1.vlines(Q_nu1_13DaLo_668, 0, Q_nu1_13DaLo_668_int, "red", linewidth=.5)
ax1.vlines(R_nu1_13DaLo_668, 0, R_nu1_13DaLo_668_int, "red", linewidth=.5)

ax1.vlines(P_nu2_13DaLo_668, 0, P_nu2_13DaLo_668_int, "red", linewidth=.5)
ax1.vlines(Q_nu2_13DaLo_668, 0, Q_nu2_13DaLo_668_int, "red", linewidth=.5)
ax1.vlines(R_nu2_13DaLo_668, 0, R_nu2_13DaLo_668_int, "red", linewidth=.5)

ax1.vlines(P_nu3_13DaLo_668, 0, P_nu3_13DaLo_668_int, "red", linewidth=.5)
ax1.vlines(Q_nu3_13DaLo_668, 0, Q_nu3_13DaLo_668_int, "red", linewidth=.5)
ax1.vlines(R_nu3_13DaLo_668, 0, R_nu3_13DaLo_668_int, "red", linewidth=.5)

ax1.vlines(HITRAN_freq_668_13DaLo,0, -HITRAN_int_668_13DaLo, color="k", label="HITRAN 2020", linewidth=.5)


#ax2

ax2.vlines(P_nu1_13DaLo_686, 0, P_nu1_13DaLo_686_int, "red", label="Ozone 686 - Epimetheus (13DaLo)", linewidth=.5)
ax2.vlines(Q_nu1_13DaLo_686, 0, Q_nu1_13DaLo_686_int, "red", linewidth=.5)
ax2.vlines(R_nu1_13DaLo_686, 0, R_nu1_13DaLo_686_int, "red", linewidth=.5)

ax2.vlines(P_nu2_13DaLo_686, 0, P_nu2_13DaLo_686_int, "red", linewidth=.5)
ax2.vlines(Q_nu2_13DaLo_686, 0, Q_nu2_13DaLo_686_int, "red", linewidth=.5)
ax2.vlines(R_nu2_13DaLo_686, 0, R_nu2_13DaLo_686_int, "red", linewidth=.5)

ax2.vlines(P_nu3_13DaLo_686, 0, P_nu3_13DaLo_686_int, "red", linewidth=.5)
ax2.vlines(Q_nu3_13DaLo_686, 0, Q_nu3_13DaLo_686_int, "red", linewidth=.5)
ax2.vlines(R_nu3_13DaLo_686, 0, R_nu3_13DaLo_686_int, "red", linewidth=.5)

ax2.vlines(HITRAN_freq_686_13DaLo,0, -HITRAN_int_686_13DaLo, color="k", label="HITRAN 2020", linewidth=.5)


#ax3

ax3.vlines(P_nu1_13DaLo_667, 0, P_nu1_13DaLo_667_int, "red", label="Ozone 667 - Epimetheus (13DaLo)", linewidth=.5)
ax3.vlines(Q_nu1_13DaLo_667, 0, Q_nu1_13DaLo_667_int, "red", linewidth=.5)
ax3.vlines(R_nu1_13DaLo_667, 0, R_nu1_13DaLo_667_int, "red", linewidth=.5)

ax3.vlines(P_nu2_13DaLo_667, 0, P_nu2_13DaLo_667_int, "red", linewidth=.5)
ax3.vlines(Q_nu2_13DaLo_667, 0, Q_nu2_13DaLo_667_int, "red", linewidth=.5)
ax3.vlines(R_nu2_13DaLo_667, 0, R_nu2_13DaLo_667_int, "red", linewidth=.5)

ax3.vlines(P_nu3_13DaLo_667, 0, P_nu3_13DaLo_667_int, "red", linewidth=.5)
ax3.vlines(Q_nu3_13DaLo_667, 0, Q_nu3_13DaLo_667_int, "red", linewidth=.5)
ax3.vlines(R_nu3_13DaLo_667, 0, R_nu3_13DaLo_667_int, "red", linewidth=.5)

ax3.vlines(HITRAN_freq_667_13DaLo,0, -HITRAN_int_667_13DaLo, color="k", label="HITRAN 2020", linewidth=.5)


#Lims
ax1.set_xlim(550, 1250)
ax2.set_xlim(550, 1250)
ax3.set_xlim(550, 1250)

#Label Subplots
ax1.annotate('(A)', xy=(0.95, 0.9), xycoords="axes fraction", fontsize=16)
ax2.annotate('(B)', xy=(0.95, 0.9), xycoords="axes fraction", fontsize=16)
ax3.annotate('(C)', xy=(0.95, 0.9), xycoords="axes fraction", fontsize=16)

plt.subplots_adjust(wspace=0, hspace=0)

fig.text(0.05, 0.5, r"Normalized Intensity, $\frac{N_J}{N}$", va='center', rotation='vertical', fontsize=16)
ax3.set_xlabel(r"Wavenumber (cm$^{-1}$)", fontsize=16)

legend = ax1.legend(loc='lower left', fontsize=16)
for handl in legend.legendHandles:
    handl.set_linewidth(3)
legend = ax2.legend(loc='lower left', fontsize=16)
for handl in legend.legendHandles:
    handl.set_linewidth(3)
legend = ax3.legend(loc='lower left', fontsize=16)
for handl in legend.legendHandles:
    handl.set_linewidth(3)

plt.savefig(f"EPI_O3_668_686_667_megamix.pdf")

plt.show()

# %%
#676 Read In
# %store -r P_nu1_13DaLo_676
# %store -r P_nu1_13DaLo_676_int
# %store -r Q_nu1_13DaLo_676
# %store -r Q_nu1_13DaLo_676_int
# %store -r R_nu1_13DaLo_676
# %store -r R_nu1_13DaLo_676_int
# %store -r P_nu2_13DaLo_676
# %store -r P_nu2_13DaLo_676_int
# %store -r Q_nu2_13DaLo_676
# %store -r Q_nu2_13DaLo_676_int
# %store -r R_nu2_13DaLo_676
# %store -r R_nu2_13DaLo_676_int
# %store -r P_nu3_13DaLo_676
# %store -r P_nu3_13DaLo_676_int
# %store -r Q_nu3_13DaLo_676
# %store -r Q_nu3_13DaLo_676_int
# %store -r R_nu3_13DaLo_676
# %store -r R_nu3_13DaLo_676_int
# %store -r HITRAN_freq_676_13DaLo
# %store -r HITRAN_int_676_13DaLo

# %%
#868 Read In
# %store -r P_nu1_13DaLo_868
# %store -r P_nu1_13DaLo_868_int
# %store -r Q_nu1_13DaLo_868
# %store -r Q_nu1_13DaLo_868_int
# %store -r R_nu1_13DaLo_868
# %store -r R_nu1_13DaLo_868_int
# %store -r P_nu2_13DaLo_868
# %store -r P_nu2_13DaLo_868_int
# %store -r Q_nu2_13DaLo_868
# %store -r Q_nu2_13DaLo_868_int
# %store -r R_nu2_13DaLo_868
# %store -r R_nu2_13DaLo_868_int
# %store -r P_nu3_13DaLo_868
# %store -r P_nu3_13DaLo_868_int
# %store -r Q_nu3_13DaLo_868
# %store -r Q_nu3_13DaLo_868_int
# %store -r R_nu3_13DaLo_868
# %store -r R_nu3_13DaLo_868_int
# %store -r HITRAN_freq_868_13DaLo
# %store -r HITRAN_int_868_13DaLo

# %%
#888 Read In
# %store -r P_nu1_13DaLo_888
# %store -r P_nu1_13DaLo_888_int
# %store -r Q_nu1_13DaLo_888
# %store -r Q_nu1_13DaLo_888_int
# %store -r R_nu1_13DaLo_888
# %store -r R_nu1_13DaLo_888_int
# %store -r P_nu2_13DaLo_888
# %store -r P_nu2_13DaLo_888_int
# %store -r Q_nu2_13DaLo_888
# %store -r Q_nu2_13DaLo_888_int
# %store -r R_nu2_13DaLo_888
# %store -r R_nu2_13DaLo_888_int
# %store -r P_nu3_13DaLo_888
# %store -r P_nu3_13DaLo_888_int
# %store -r Q_nu3_13DaLo_888
# %store -r Q_nu3_13DaLo_888_int
# %store -r R_nu3_13DaLo_888
# %store -r R_nu3_13DaLo_888_int
# %store -r HITRAN_freq_888_13DaLo
# %store -r HITRAN_int_888_13DaLo

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex="row", figsize=(16,16))

#ax1
ax1.vlines(P_nu1_13DaLo_676, 0, P_nu1_13DaLo_676_int, "red", label="Ozone 676 - Epimetheus (13DaLo)", linewidth=.5)
ax1.vlines(Q_nu1_13DaLo_676, 0, Q_nu1_13DaLo_676_int, "red", linewidth=.5)
ax1.vlines(R_nu1_13DaLo_676, 0, R_nu1_13DaLo_676_int, "red", linewidth=.5)

ax1.vlines(P_nu2_13DaLo_676, 0, P_nu2_13DaLo_676_int, "red", linewidth=.5)
ax1.vlines(Q_nu2_13DaLo_676, 0, Q_nu2_13DaLo_676_int, "red", linewidth=.5)
ax1.vlines(R_nu2_13DaLo_676, 0, R_nu2_13DaLo_676_int, "red", linewidth=.5)

ax1.vlines(P_nu3_13DaLo_676, 0, P_nu3_13DaLo_676_int, "red", linewidth=.5)
ax1.vlines(Q_nu3_13DaLo_676, 0, Q_nu3_13DaLo_676_int, "red", linewidth=.5)
ax1.vlines(R_nu3_13DaLo_676, 0, R_nu3_13DaLo_676_int, "red", linewidth=.5)

ax1.vlines(HITRAN_freq_676_13DaLo,0, -HITRAN_int_676_13DaLo, color="k", label="HITRAN 2020", linewidth=.5)

#ax2
ax2.vlines(P_nu1_13DaLo_868, 0, P_nu1_13DaLo_868_int, "red", label="Ozone 868 - Epimetheus (13DaLo)", linewidth=.5)
ax2.vlines(Q_nu1_13DaLo_868, 0, Q_nu1_13DaLo_868_int, "red", linewidth=.5)
ax2.vlines(R_nu1_13DaLo_868, 0, R_nu1_13DaLo_868_int, "red", linewidth=.5)

ax2.vlines(P_nu2_13DaLo_868, 0, P_nu2_13DaLo_868_int, "red", linewidth=.5)
ax2.vlines(Q_nu2_13DaLo_868, 0, Q_nu2_13DaLo_868_int, "red", linewidth=.5)
ax2.vlines(R_nu2_13DaLo_868, 0, R_nu2_13DaLo_868_int, "red", linewidth=.5)

ax2.vlines(P_nu3_13DaLo_868, 0, P_nu3_13DaLo_868_int, "red", linewidth=.5)
ax2.vlines(Q_nu3_13DaLo_868, 0, Q_nu3_13DaLo_868_int, "red", linewidth=.5)
ax2.vlines(R_nu3_13DaLo_868, 0, R_nu3_13DaLo_868_int, "red", linewidth=.5)

ax2.vlines(HITRAN_freq_868_13DaLo,0, -HITRAN_int_868_13DaLo, color="k", label="S&MPO-2020d", linewidth=.5)

#ax3
ax3.vlines(P_nu1_13DaLo_888, 0, P_nu1_13DaLo_888_int, "red", label="Ozone 888 - Epimetheus (13DaLo)", linewidth=.5)
ax3.vlines(Q_nu1_13DaLo_888, 0, Q_nu1_13DaLo_888_int, "red", linewidth=.5)
ax3.vlines(R_nu1_13DaLo_888, 0, R_nu1_13DaLo_888_int, "red", linewidth=.5)

ax3.vlines(P_nu2_13DaLo_888, 0, P_nu2_13DaLo_888_int, "red", linewidth=.5)
ax3.vlines(Q_nu2_13DaLo_888, 0, Q_nu2_13DaLo_888_int, "red", linewidth=.5)
ax3.vlines(R_nu2_13DaLo_888, 0, R_nu2_13DaLo_888_int, "red", linewidth=.5)

ax3.vlines(P_nu3_13DaLo_888, 0, P_nu3_13DaLo_888_int, "red", linewidth=.5)
ax3.vlines(Q_nu3_13DaLo_888, 0, Q_nu3_13DaLo_888_int, "red", linewidth=.5)
ax3.vlines(R_nu3_13DaLo_888, 0, R_nu3_13DaLo_888_int, "red", linewidth=.5)

ax3.vlines(HITRAN_freq_888_13DaLo,0, -HITRAN_int_888_13DaLo, color="k", label="S&MPO-2020d", linewidth=.5)

#Lims
ax1.set_xlim(550, 1250)
ax2.set_xlim(550, 1250)
ax3.set_xlim(550, 1250)

#Label Subplots
ax1.annotate('(A)', xy=(0.95, 0.9), xycoords="axes fraction", fontsize=16)
ax2.annotate('(B)', xy=(0.95, 0.9), xycoords="axes fraction", fontsize=16)
ax3.annotate('(C)', xy=(0.95, 0.9), xycoords="axes fraction", fontsize=16)

plt.subplots_adjust(wspace=0, hspace=0)

fig.text(0.05, 0.5, r"Normalized Intensity, $\frac{N_J}{N}$", va='center', rotation='vertical', fontsize=16)
ax3.set_xlabel(r"Wavenumber (cm$^{-1}$)", fontsize=16)

legend = ax1.legend(loc='lower left', fontsize=16)
for handl in legend.legendHandles:
    handl.set_linewidth(3)
legend = ax2.legend(loc='lower left', fontsize=16)
for handl in legend.legendHandles:
    handl.set_linewidth(3)
legend = ax3.legend(loc='lower left', fontsize=16)
for handl in legend.legendHandles:
    handl.set_linewidth(3)

plt.savefig(f"EPI_O3_676_868_888_megamix.pdf")

plt.show()
